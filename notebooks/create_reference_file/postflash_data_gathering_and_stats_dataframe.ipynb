# %%
import glob
import os
import shutil

from astropy.io import ascii
from astropy.io import fits
from astropy.table import Table
from astroquery.mast import Observations

import numpy as np
import pandas as pd

# %matplotlib inline

# %%
postflash_proposal_list = [16570,16982] #[13078,13560,14006,14372,14535,14984,15573,15718,16398,16570,16982]
working_directory = '/Users/cmartlin/Desktop/postflash_2022/'
database_filename = working_directory + '/Jan_2023_all_postflash_flc.pkl'

# %%
postflash_proposals = Observations.query_criteria(proposal_id=postflash_proposal_list)

science_list = postflash_proposals

Observations.download_products(science_list['obsid'], mrp_only=False, download_dir='./science',
                                productSubGroupDescription=['FLC', 'RAW'])
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07raq_raw.fits to ./science/mastDownload/HST/ielu07raq/ielu07raq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07raq_flc.fits to ./science/mastDownload/HST/ielu07raq/ielu07raq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu06q5q_raw.fits to ./science/mastDownload/HST/ielu06q5q/ielu06q5q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu06q5q_flc.fits to ./science/mastDownload/HST/ielu06q5q/ielu06q5q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07qxq_raw.fits to ./science/mastDownload/HST/ielu07qxq/ielu07qxq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07qxq_flc.fits to ./science/mastDownload/HST/ielu07qxq/ielu07qxq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07rgq_raw.fits to ./science/mastDownload/HST/ielu07rgq/ielu07rgq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07rgq_flc.fits to ./science/mastDownload/HST/ielu07rgq/ielu07rgq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r3q_raw.fits to ./science/mastDownload/HST/ielu07r3q/ielu07r3q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r3q_flc.fits to ./science/mastDownload/HST/ielu07r3q/ielu07r3q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r9q_raw.fits to ./science/mastDownload/HST/ielu07r9q/ielu07r9q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r9q_flc.fits to ./science/mastDownload/HST/ielu07r9q/ielu07r9q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qhq_raw.fits to ./science/mastDownload/HST/ielu08qhq/ielu08qhq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qhq_flc.fits to ./science/mastDownload/HST/ielu08qhq/ielu08qhq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qmq_raw.fits to ./science/mastDownload/HST/ielu08qmq/ielu08qmq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qmq_flc.fits to ./science/mastDownload/HST/ielu08qmq/ielu08qmq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qdq_raw.fits to ./science/mastDownload/HST/ielu08qdq/ielu08qdq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qdq_flc.fits to ./science/mastDownload/HST/ielu08qdq/ielu08qdq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qeq_raw.fits to ./science/mastDownload/HST/ielu08qeq/ielu08qeq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qeq_flc.fits to ./science/mastDownload/HST/ielu08qeq/ielu08qeq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qbq_raw.fits to ./science/mastDownload/HST/ielu08qbq/ielu08qbq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qbq_flc.fits to ./science/mastDownload/HST/ielu08qbq/ielu08qbq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qgq_raw.fits to ./science/mastDownload/HST/ielu08qgq/ielu08qgq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qgq_flc.fits to ./science/mastDownload/HST/ielu08qgq/ielu08qgq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qlq_raw.fits to ./science/mastDownload/HST/ielu08qlq/ielu08qlq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qlq_flc.fits to ./science/mastDownload/HST/ielu08qlq/ielu08qlq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qfq_raw.fits to ./science/mastDownload/HST/ielu08qfq/ielu08qfq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qfq_flc.fits to ./science/mastDownload/HST/ielu08qfq/ielu08qfq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qjq_raw.fits to ./science/mastDownload/HST/ielu08qjq/ielu08qjq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qjq_flc.fits to ./science/mastDownload/HST/ielu08qjq/ielu08qjq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qkq_raw.fits to ./science/mastDownload/HST/ielu08qkq/ielu08qkq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qkq_flc.fits to ./science/mastDownload/HST/ielu08qkq/ielu08qkq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qcq_raw.fits to ./science/mastDownload/HST/ielu08qcq/ielu08qcq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qcq_flc.fits to ./science/mastDownload/HST/ielu08qcq/ielu08qcq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qaq_raw.fits to ./science/mastDownload/HST/ielu08qaq/ielu08qaq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08qaq_flc.fits to ./science/mastDownload/HST/ielu08qaq/ielu08qaq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08q9q_raw.fits to ./science/mastDownload/HST/ielu08q9q/ielu08q9q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08q9q_flc.fits to ./science/mastDownload/HST/ielu08q9q/ielu08q9q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07rfq_raw.fits to ./science/mastDownload/HST/ielu07rfq/ielu07rfq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07rfq_flc.fits to ./science/mastDownload/HST/ielu07rfq/ielu07rfq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07rbq_raw.fits to ./science/mastDownload/HST/ielu07rbq/ielu07rbq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07rbq_flc.fits to ./science/mastDownload/HST/ielu07rbq/ielu07rbq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r8q_raw.fits to ./science/mastDownload/HST/ielu07r8q/ielu07r8q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r8q_flc.fits to ./science/mastDownload/HST/ielu07r8q/ielu07r8q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r6q_raw.fits to ./science/mastDownload/HST/ielu07r6q/ielu07r6q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r6q_flc.fits to ./science/mastDownload/HST/ielu07r6q/ielu07r6q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08q8q_raw.fits to ./science/mastDownload/HST/ielu08q8q/ielu08q8q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu08q8q_flc.fits to ./science/mastDownload/HST/ielu08q8q/ielu08q8q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07qyq_raw.fits to ./science/mastDownload/HST/ielu07qyq/ielu07qyq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07qyq_flc.fits to ./science/mastDownload/HST/ielu07qyq/ielu07qyq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r0q_raw.fits to ./science/mastDownload/HST/ielu07r0q/ielu07r0q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r0q_flc.fits to ./science/mastDownload/HST/ielu07r0q/ielu07r0q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07rdq_raw.fits to ./science/mastDownload/HST/ielu07rdq/ielu07rdq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07rdq_flc.fits to ./science/mastDownload/HST/ielu07rdq/ielu07rdq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r2q_raw.fits to ./science/mastDownload/HST/ielu07r2q/ielu07r2q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r2q_flc.fits to ./science/mastDownload/HST/ielu07r2q/ielu07r2q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r4q_raw.fits to ./science/mastDownload/HST/ielu07r4q/ielu07r4q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu07r4q_flc.fits to ./science/mastDownload/HST/ielu07r4q/ielu07r4q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu06pwq_raw.fits to ./science/mastDownload/HST/ielu06pwq/ielu06pwq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu06pwq_flc.fits to ./science/mastDownload/HST/ielu06pwq/ielu06pwq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu05rnq_raw.fits to ./science/mastDownload/HST/ielu05rnq/ielu05rnq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu05rnq_flc.fits to ./science/mastDownload/HST/ielu05rnq/ielu05rnq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu05rkq_raw.fits to ./science/mastDownload/HST/ielu05rkq/ielu05rkq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu05rkq_flc.fits to ./science/mastDownload/HST/ielu05rkq/ielu05rkq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu05rjq_raw.fits to ./science/mastDownload/HST/ielu05rjq/ielu05rjq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu05rjq_flc.fits to ./science/mastDownload/HST/ielu05rjq/ielu05rjq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu06pvq_raw.fits to ./science/mastDownload/HST/ielu06pvq/ielu06pvq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu06pvq_flc.fits to ./science/mastDownload/HST/ielu06pvq/ielu06pvq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu05rmq_raw.fits to ./science/mastDownload/HST/ielu05rmq/ielu05rmq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu05rmq_flc.fits to ./science/mastDownload/HST/ielu05rmq/ielu05rmq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu06q4q_raw.fits to ./science/mastDownload/HST/ielu06q4q/ielu06q4q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu06q4q_flc.fits to ./science/mastDownload/HST/ielu06q4q/ielu06q4q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu59h5q_flc.fits to ./science/mastDownload/HST/ielu59h5q/ielu59h5q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu59h5q_raw.fits to ./science/mastDownload/HST/ielu59h5q/ielu59h5q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu59h6q_flc.fits to ./science/mastDownload/HST/ielu59h6q/ielu59h6q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu59h6q_raw.fits to ./science/mastDownload/HST/ielu59h6q/ielu59h6q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu59h8q_flc.fits to ./science/mastDownload/HST/ielu59h8q/ielu59h8q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu59h8q_raw.fits to ./science/mastDownload/HST/ielu59h8q/ielu59h8q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu58giq_flc.fits to ./science/mastDownload/HST/ielu58giq/ielu58giq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu58giq_raw.fits to ./science/mastDownload/HST/ielu58giq/ielu58giq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu58gjq_flc.fits to ./science/mastDownload/HST/ielu58gjq/ielu58gjq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu58gjq_raw.fits to ./science/mastDownload/HST/ielu58gjq/ielu58gjq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu58glq_flc.fits to ./science/mastDownload/HST/ielu58glq/ielu58glq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu58glq_raw.fits to ./science/mastDownload/HST/ielu58glq/ielu58glq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu56cgq_flc.fits to ./science/mastDownload/HST/ielu56cgq/ielu56cgq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu56cgq_raw.fits to ./science/mastDownload/HST/ielu56cgq/ielu56cgq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu56chq_flc.fits to ./science/mastDownload/HST/ielu56chq/ielu56chq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu56chq_raw.fits to ./science/mastDownload/HST/ielu56chq/ielu56chq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu56cjq_flc.fits to ./science/mastDownload/HST/ielu56cjq/ielu56cjq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu56cjq_raw.fits to ./science/mastDownload/HST/ielu56cjq/ielu56cjq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu53x0q_flc.fits to ./science/mastDownload/HST/ielu53x0q/ielu53x0q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu53x0q_raw.fits to ./science/mastDownload/HST/ielu53x0q/ielu53x0q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu53x1q_flc.fits to ./science/mastDownload/HST/ielu53x1q/ielu53x1q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu53x1q_raw.fits to ./science/mastDownload/HST/ielu53x1q/ielu53x1q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu53x3q_flc.fits to ./science/mastDownload/HST/ielu53x3q/ielu53x3q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu53x3q_raw.fits to ./science/mastDownload/HST/ielu53x3q/ielu53x3q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu50scq_flc.fits to ./science/mastDownload/HST/ielu50scq/ielu50scq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu50scq_raw.fits to ./science/mastDownload/HST/ielu50scq/ielu50scq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu50sdq_flc.fits to ./science/mastDownload/HST/ielu50sdq/ielu50sdq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu50sdq_raw.fits to ./science/mastDownload/HST/ielu50sdq/ielu50sdq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu50sfq_flc.fits to ./science/mastDownload/HST/ielu50sfq/ielu50sfq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu50sfq_raw.fits to ./science/mastDownload/HST/ielu50sfq/ielu50sfq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu52wvq_flc.fits to ./science/mastDownload/HST/ielu52wvq/ielu52wvq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu52wvq_raw.fits to ./science/mastDownload/HST/ielu52wvq/ielu52wvq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu52wwq_flc.fits to ./science/mastDownload/HST/ielu52wwq/ielu52wwq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu52wwq_raw.fits to ./science/mastDownload/HST/ielu52wwq/ielu52wwq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu52wyq_flc.fits to ./science/mastDownload/HST/ielu52wyq/ielu52wyq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu52wyq_raw.fits to ./science/mastDownload/HST/ielu52wyq/ielu52wyq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu49r0q_flc.fits to ./science/mastDownload/HST/ielu49r0q/ielu49r0q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu49r0q_raw.fits to ./science/mastDownload/HST/ielu49r0q/ielu49r0q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu49r1q_flc.fits to ./science/mastDownload/HST/ielu49r1q/ielu49r1q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu49r1q_raw.fits to ./science/mastDownload/HST/ielu49r1q/ielu49r1q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu49r3q_flc.fits to ./science/mastDownload/HST/ielu49r3q/ielu49r3q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu49r3q_raw.fits to ./science/mastDownload/HST/ielu49r3q/ielu49r3q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu46j9q_flc.fits to ./science/mastDownload/HST/ielu46j9q/ielu46j9q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu46j9q_raw.fits to ./science/mastDownload/HST/ielu46j9q/ielu46j9q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu46jaq_flc.fits to ./science/mastDownload/HST/ielu46jaq/ielu46jaq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu46jaq_raw.fits to ./science/mastDownload/HST/ielu46jaq/ielu46jaq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu46jcq_flc.fits to ./science/mastDownload/HST/ielu46jcq/ielu46jcq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu46jcq_raw.fits to ./science/mastDownload/HST/ielu46jcq/ielu46jcq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu47lqq_flc.fits to ./science/mastDownload/HST/ielu47lqq/ielu47lqq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu47lqq_raw.fits to ./science/mastDownload/HST/ielu47lqq/ielu47lqq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu47lrq_flc.fits to ./science/mastDownload/HST/ielu47lrq/ielu47lrq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu47lrq_raw.fits to ./science/mastDownload/HST/ielu47lrq/ielu47lrq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu47ltq_flc.fits to ./science/mastDownload/HST/ielu47ltq/ielu47ltq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu47ltq_raw.fits to ./science/mastDownload/HST/ielu47ltq/ielu47ltq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu44gmq_flc.fits to ./science/mastDownload/HST/ielu44gmq/ielu44gmq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu44gmq_raw.fits to ./science/mastDownload/HST/ielu44gmq/ielu44gmq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu44gnq_flc.fits to ./science/mastDownload/HST/ielu44gnq/ielu44gnq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu44gnq_raw.fits to ./science/mastDownload/HST/ielu44gnq/ielu44gnq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu44gqq_flc.fits to ./science/mastDownload/HST/ielu44gqq/ielu44gqq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu44gqq_raw.fits to ./science/mastDownload/HST/ielu44gqq/ielu44gqq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu43gfq_flc.fits to ./science/mastDownload/HST/ielu43gfq/ielu43gfq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu43gfq_raw.fits to ./science/mastDownload/HST/ielu43gfq/ielu43gfq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu43ggq_flc.fits to ./science/mastDownload/HST/ielu43ggq/ielu43ggq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu43ggq_raw.fits to ./science/mastDownload/HST/ielu43ggq/ielu43ggq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu43gjq_flc.fits to ./science/mastDownload/HST/ielu43gjq/ielu43gjq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu43gjq_raw.fits to ./science/mastDownload/HST/ielu43gjq/ielu43gjq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu55c4q_flc.fits to ./science/mastDownload/HST/ielu55c4q/ielu55c4q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu55c4q_raw.fits to ./science/mastDownload/HST/ielu55c4q/ielu55c4q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu55c5q_flc.fits to ./science/mastDownload/HST/ielu55c5q/ielu55c5q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu55c5q_raw.fits to ./science/mastDownload/HST/ielu55c5q/ielu55c5q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu55c7q_flc.fits to ./science/mastDownload/HST/ielu55c7q/ielu55c7q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu55c7q_raw.fits to ./science/mastDownload/HST/ielu55c7q/ielu55c7q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu60j7q_flc.fits to ./science/mastDownload/HST/ielu60j7q/ielu60j7q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu60j7q_raw.fits to ./science/mastDownload/HST/ielu60j7q/ielu60j7q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu60j8q_flc.fits to ./science/mastDownload/HST/ielu60j8q/ielu60j8q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu60j8q_raw.fits to ./science/mastDownload/HST/ielu60j8q/ielu60j8q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu60kdq_flc.fits to ./science/mastDownload/HST/ielu60kdq/ielu60kdq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu60kdq_raw.fits to ./science/mastDownload/HST/ielu60kdq/ielu60kdq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu54bqq_flc.fits to ./science/mastDownload/HST/ielu54bqq/ielu54bqq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu54bqq_raw.fits to ./science/mastDownload/HST/ielu54bqq/ielu54bqq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu54brq_flc.fits to ./science/mastDownload/HST/ielu54brq/ielu54brq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu54brq_raw.fits to ./science/mastDownload/HST/ielu54brq/ielu54brq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu54btq_flc.fits to ./science/mastDownload/HST/ielu54btq/ielu54btq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu54btq_raw.fits to ./science/mastDownload/HST/ielu54btq/ielu54btq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu48nqq_flc.fits to ./science/mastDownload/HST/ielu48nqq/ielu48nqq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu48nqq_raw.fits to ./science/mastDownload/HST/ielu48nqq/ielu48nqq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu48nuq_flc.fits to ./science/mastDownload/HST/ielu48nuq/ielu48nuq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu48nuq_raw.fits to ./science/mastDownload/HST/ielu48nuq/ielu48nuq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu48onq_flc.fits to ./science/mastDownload/HST/ielu48onq/ielu48onq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu48onq_raw.fits to ./science/mastDownload/HST/ielu48onq/ielu48onq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu51t5q_flc.fits to ./science/mastDownload/HST/ielu51t5q/ielu51t5q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu51t5q_raw.fits to ./science/mastDownload/HST/ielu51t5q/ielu51t5q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu51t6q_flc.fits to ./science/mastDownload/HST/ielu51t6q/ielu51t6q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu51t6q_raw.fits to ./science/mastDownload/HST/ielu51t6q/ielu51t6q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu51t9q_flc.fits to ./science/mastDownload/HST/ielu51t9q/ielu51t9q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu51t9q_raw.fits to ./science/mastDownload/HST/ielu51t9q/ielu51t9q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu57deq_flc.fits to ./science/mastDownload/HST/ielu57deq/ielu57deq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu57deq_raw.fits to ./science/mastDownload/HST/ielu57deq/ielu57deq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu57dfq_flc.fits to ./science/mastDownload/HST/ielu57dfq/ielu57dfq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu57dfq_raw.fits to ./science/mastDownload/HST/ielu57dfq/ielu57dfq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu57dhq_flc.fits to ./science/mastDownload/HST/ielu57dhq/ielu57dhq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu57dhq_raw.fits to ./science/mastDownload/HST/ielu57dhq/ielu57dhq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu45isq_flc.fits to ./science/mastDownload/HST/ielu45isq/ielu45isq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu45isq_raw.fits to ./science/mastDownload/HST/ielu45isq/ielu45isq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu45itq_flc.fits to ./science/mastDownload/HST/ielu45itq/ielu45itq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu45itq_raw.fits to ./science/mastDownload/HST/ielu45itq/ielu45itq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu45ivq_flc.fits to ./science/mastDownload/HST/ielu45ivq/ielu45ivq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu45ivq_raw.fits to ./science/mastDownload/HST/ielu45ivq/ielu45ivq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12psq_raw.fits to ./science/mastDownload/HST/ielu12psq/ielu12psq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12psq_flc.fits to ./science/mastDownload/HST/ielu12psq/ielu12psq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12ppq_raw.fits to ./science/mastDownload/HST/ielu12ppq/ielu12ppq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12ppq_flc.fits to ./science/mastDownload/HST/ielu12ppq/ielu12ppq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu10luq_raw.fits to ./science/mastDownload/HST/ielu10luq/ielu10luq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu10luq_flc.fits to ./science/mastDownload/HST/ielu10luq/ielu10luq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12prq_raw.fits to ./science/mastDownload/HST/ielu12prq/ielu12prq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12prq_flc.fits to ./science/mastDownload/HST/ielu12prq/ielu12prq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pwq_raw.fits to ./science/mastDownload/HST/ielu12pwq/ielu12pwq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pwq_flc.fits to ./science/mastDownload/HST/ielu12pwq/ielu12pwq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12ptq_raw.fits to ./science/mastDownload/HST/ielu12ptq/ielu12ptq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12ptq_flc.fits to ./science/mastDownload/HST/ielu12ptq/ielu12ptq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pnq_raw.fits to ./science/mastDownload/HST/ielu12pnq/ielu12pnq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pnq_flc.fits to ./science/mastDownload/HST/ielu12pnq/ielu12pnq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11mtq_raw.fits to ./science/mastDownload/HST/ielu11mtq/ielu11mtq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11mtq_flc.fits to ./science/mastDownload/HST/ielu11mtq/ielu11mtq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11msq_raw.fits to ./science/mastDownload/HST/ielu11msq/ielu11msq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11msq_flc.fits to ./science/mastDownload/HST/ielu11msq/ielu11msq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu09qbq_raw.fits to ./science/mastDownload/HST/ielu09qbq/ielu09qbq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu09qbq_flc.fits to ./science/mastDownload/HST/ielu09qbq/ielu09qbq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11muq_raw.fits to ./science/mastDownload/HST/ielu11muq/ielu11muq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11muq_flc.fits to ./science/mastDownload/HST/ielu11muq/ielu11muq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu10lwq_raw.fits to ./science/mastDownload/HST/ielu10lwq/ielu10lwq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu10lwq_flc.fits to ./science/mastDownload/HST/ielu10lwq/ielu10lwq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n5q_raw.fits to ./science/mastDownload/HST/ielu11n5q/ielu11n5q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n5q_flc.fits to ./science/mastDownload/HST/ielu11n5q/ielu11n5q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11mxq_raw.fits to ./science/mastDownload/HST/ielu11mxq/ielu11mxq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11mxq_flc.fits to ./science/mastDownload/HST/ielu11mxq/ielu11mxq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11myq_raw.fits to ./science/mastDownload/HST/ielu11myq/ielu11myq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11myq_flc.fits to ./science/mastDownload/HST/ielu11myq/ielu11myq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n2q_raw.fits to ./science/mastDownload/HST/ielu11n2q/ielu11n2q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n2q_flc.fits to ./science/mastDownload/HST/ielu11n2q/ielu11n2q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pqq_raw.fits to ./science/mastDownload/HST/ielu12pqq/ielu12pqq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pqq_flc.fits to ./science/mastDownload/HST/ielu12pqq/ielu12pqq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu09qcq_raw.fits to ./science/mastDownload/HST/ielu09qcq/ielu09qcq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu09qcq_flc.fits to ./science/mastDownload/HST/ielu09qcq/ielu09qcq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pyq_raw.fits to ./science/mastDownload/HST/ielu12pyq/ielu12pyq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pyq_flc.fits to ./science/mastDownload/HST/ielu12pyq/ielu12pyq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12q0q_raw.fits to ./science/mastDownload/HST/ielu12q0q/ielu12q0q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12q0q_flc.fits to ./science/mastDownload/HST/ielu12q0q/ielu12q0q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n6q_raw.fits to ./science/mastDownload/HST/ielu11n6q/ielu11n6q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n6q_flc.fits to ./science/mastDownload/HST/ielu11n6q/ielu11n6q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12puq_raw.fits to ./science/mastDownload/HST/ielu12puq/ielu12puq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12puq_flc.fits to ./science/mastDownload/HST/ielu12puq/ielu12puq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pzq_raw.fits to ./science/mastDownload/HST/ielu12pzq/ielu12pzq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pzq_flc.fits to ./science/mastDownload/HST/ielu12pzq/ielu12pzq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pxq_raw.fits to ./science/mastDownload/HST/ielu12pxq/ielu12pxq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pxq_flc.fits to ./science/mastDownload/HST/ielu12pxq/ielu12pxq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n7q_raw.fits to ./science/mastDownload/HST/ielu11n7q/ielu11n7q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n7q_flc.fits to ./science/mastDownload/HST/ielu11n7q/ielu11n7q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pvq_raw.fits to ./science/mastDownload/HST/ielu12pvq/ielu12pvq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12pvq_flc.fits to ./science/mastDownload/HST/ielu12pvq/ielu12pvq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu09q4q_raw.fits to ./science/mastDownload/HST/ielu09q4q/ielu09q4q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu09q4q_flc.fits to ./science/mastDownload/HST/ielu09q4q/ielu09q4q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n1q_raw.fits to ./science/mastDownload/HST/ielu11n1q/ielu11n1q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n1q_flc.fits to ./science/mastDownload/HST/ielu11n1q/ielu11n1q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11mzq_raw.fits to ./science/mastDownload/HST/ielu11mzq/ielu11mzq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11mzq_flc.fits to ./science/mastDownload/HST/ielu11mzq/ielu11mzq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n3q_raw.fits to ./science/mastDownload/HST/ielu11n3q/ielu11n3q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n3q_flc.fits to ./science/mastDownload/HST/ielu11n3q/ielu11n3q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n0q_raw.fits to ./science/mastDownload/HST/ielu11n0q/ielu11n0q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11n0q_flc.fits to ./science/mastDownload/HST/ielu11n0q/ielu11n0q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu09q2q_raw.fits to ./science/mastDownload/HST/ielu09q2q/ielu09q2q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu09q2q_flc.fits to ./science/mastDownload/HST/ielu09q2q/ielu09q2q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12poq_raw.fits to ./science/mastDownload/HST/ielu12poq/ielu12poq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu12poq_flc.fits to ./science/mastDownload/HST/ielu12poq/ielu12poq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11mwq_raw.fits to ./science/mastDownload/HST/ielu11mwq/ielu11mwq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu11mwq_flc.fits to ./science/mastDownload/HST/ielu11mwq/ielu11mwq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu10ltq_raw.fits to ./science/mastDownload/HST/ielu10ltq/ielu10ltq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu10ltq_flc.fits to ./science/mastDownload/HST/ielu10ltq/ielu10ltq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu10lxq_raw.fits to ./science/mastDownload/HST/ielu10lxq/ielu10lxq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu10lxq_flc.fits to ./science/mastDownload/HST/ielu10lxq/ielu10lxq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jcq_raw.fits to ./science/mastDownload/HST/ielu15jcq/ielu15jcq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jcq_flc.fits to ./science/mastDownload/HST/ielu15jcq/ielu15jcq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j9q_raw.fits to ./science/mastDownload/HST/ielu15j9q/ielu15j9q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j9q_flc.fits to ./science/mastDownload/HST/ielu15j9q/ielu15j9q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jaq_raw.fits to ./science/mastDownload/HST/ielu15jaq/ielu15jaq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jaq_flc.fits to ./science/mastDownload/HST/ielu15jaq/ielu15jaq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j7q_raw.fits to ./science/mastDownload/HST/ielu15j7q/ielu15j7q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j7q_flc.fits to ./science/mastDownload/HST/ielu15j7q/ielu15j7q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j6q_raw.fits to ./science/mastDownload/HST/ielu15j6q/ielu15j6q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j6q_flc.fits to ./science/mastDownload/HST/ielu15j6q/ielu15j6q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j5q_raw.fits to ./science/mastDownload/HST/ielu15j5q/ielu15j5q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j5q_flc.fits to ./science/mastDownload/HST/ielu15j5q/ielu15j5q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jdq_raw.fits to ./science/mastDownload/HST/ielu15jdq/ielu15jdq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jdq_flc.fits to ./science/mastDownload/HST/ielu15jdq/ielu15jdq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jeq_raw.fits to ./science/mastDownload/HST/ielu15jeq/ielu15jeq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jeq_flc.fits to ./science/mastDownload/HST/ielu15jeq/ielu15jeq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j4q_raw.fits to ./science/mastDownload/HST/ielu15j4q/ielu15j4q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j4q_flc.fits to ./science/mastDownload/HST/ielu15j4q/ielu15j4q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j8q_raw.fits to ./science/mastDownload/HST/ielu15j8q/ielu15j8q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j8q_flc.fits to ./science/mastDownload/HST/ielu15j8q/ielu15j8q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jbq_raw.fits to ./science/mastDownload/HST/ielu15jbq/ielu15jbq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15jbq_flc.fits to ./science/mastDownload/HST/ielu15jbq/ielu15jbq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j3q_raw.fits to ./science/mastDownload/HST/ielu15j3q/ielu15j3q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j3q_flc.fits to ./science/mastDownload/HST/ielu15j3q/ielu15j3q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j2q_raw.fits to ./science/mastDownload/HST/ielu15j2q/ielu15j2q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu15j2q_flc.fits to ./science/mastDownload/HST/ielu15j2q/ielu15j2q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ielu14izq_raw.fits to ./science/mastDownload/HST/ielu14izq/ielu14izq_raw.fits ... [Done]
# ...
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp46wgq_raw.fits to ./science/mastDownload/HST/ieyp46wgq/ieyp46wgq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp46wmq_flc.fits to ./science/mastDownload/HST/ieyp46wmq/ieyp46wmq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp46wmq_raw.fits to ./science/mastDownload/HST/ieyp46wmq/ieyp46wmq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp44ulq_flc.fits to ./science/mastDownload/HST/ieyp44ulq/ieyp44ulq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp44ulq_raw.fits to ./science/mastDownload/HST/ieyp44ulq/ieyp44ulq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp44umq_flc.fits to ./science/mastDownload/HST/ieyp44umq/ieyp44umq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp44umq_raw.fits to ./science/mastDownload/HST/ieyp44umq/ieyp44umq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp44uoq_flc.fits to ./science/mastDownload/HST/ieyp44uoq/ieyp44uoq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp44uoq_raw.fits to ./science/mastDownload/HST/ieyp44uoq/ieyp44uoq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11scq_raw.fits to ./science/mastDownload/HST/ieyp11scq/ieyp11scq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11scq_flc.fits to ./science/mastDownload/HST/ieyp11scq/ieyp11scq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11s9q_raw.fits to ./science/mastDownload/HST/ieyp11s9q/ieyp11s9q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11s9q_flc.fits to ./science/mastDownload/HST/ieyp11s9q/ieyp11s9q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12sxq_raw.fits to ./science/mastDownload/HST/ieyp12sxq/ieyp12sxq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12sxq_flc.fits to ./science/mastDownload/HST/ieyp12sxq/ieyp12sxq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11smq_raw.fits to ./science/mastDownload/HST/ieyp11smq/ieyp11smq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11smq_flc.fits to ./science/mastDownload/HST/ieyp11smq/ieyp11smq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11slq_raw.fits to ./science/mastDownload/HST/ieyp11slq/ieyp11slq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11slq_flc.fits to ./science/mastDownload/HST/ieyp11slq/ieyp11slq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11shq_raw.fits to ./science/mastDownload/HST/ieyp11shq/ieyp11shq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11shq_flc.fits to ./science/mastDownload/HST/ieyp11shq/ieyp11shq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12szq_raw.fits to ./science/mastDownload/HST/ieyp12szq/ieyp12szq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12szq_flc.fits to ./science/mastDownload/HST/ieyp12szq/ieyp12szq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12swq_raw.fits to ./science/mastDownload/HST/ieyp12swq/ieyp12swq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12swq_flc.fits to ./science/mastDownload/HST/ieyp12swq/ieyp12swq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp10rjq_raw.fits to ./science/mastDownload/HST/ieyp10rjq/ieyp10rjq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp10rjq_flc.fits to ./science/mastDownload/HST/ieyp10rjq/ieyp10rjq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t2q_raw.fits to ./science/mastDownload/HST/ieyp12t2q/ieyp12t2q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t2q_flc.fits to ./science/mastDownload/HST/ieyp12t2q/ieyp12t2q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp09r4q_raw.fits to ./science/mastDownload/HST/ieyp09r4q/ieyp09r4q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp09r4q_flc.fits to ./science/mastDownload/HST/ieyp09r4q/ieyp09r4q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp09r3q_raw.fits to ./science/mastDownload/HST/ieyp09r3q/ieyp09r3q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp09r3q_flc.fits to ./science/mastDownload/HST/ieyp09r3q/ieyp09r3q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sjq_raw.fits to ./science/mastDownload/HST/ieyp11sjq/ieyp11sjq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sjq_flc.fits to ./science/mastDownload/HST/ieyp11sjq/ieyp11sjq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12suq_raw.fits to ./science/mastDownload/HST/ieyp12suq/ieyp12suq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12suq_flc.fits to ./science/mastDownload/HST/ieyp12suq/ieyp12suq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp10roq_raw.fits to ./science/mastDownload/HST/ieyp10roq/ieyp10roq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp10roq_flc.fits to ./science/mastDownload/HST/ieyp10roq/ieyp10roq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t4q_raw.fits to ./science/mastDownload/HST/ieyp12t4q/ieyp12t4q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t4q_flc.fits to ./science/mastDownload/HST/ieyp12t4q/ieyp12t4q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sgq_raw.fits to ./science/mastDownload/HST/ieyp11sgq/ieyp11sgq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sgq_flc.fits to ./science/mastDownload/HST/ieyp11sgq/ieyp11sgq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp10rrq_raw.fits to ./science/mastDownload/HST/ieyp10rrq/ieyp10rrq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp10rrq_flc.fits to ./science/mastDownload/HST/ieyp10rrq/ieyp10rrq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp09r8q_raw.fits to ./science/mastDownload/HST/ieyp09r8q/ieyp09r8q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp09r8q_flc.fits to ./science/mastDownload/HST/ieyp09r8q/ieyp09r8q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t6q_raw.fits to ./science/mastDownload/HST/ieyp12t6q/ieyp12t6q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t6q_flc.fits to ./science/mastDownload/HST/ieyp12t6q/ieyp12t6q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12svq_raw.fits to ./science/mastDownload/HST/ieyp12svq/ieyp12svq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12svq_flc.fits to ./science/mastDownload/HST/ieyp12svq/ieyp12svq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t3q_raw.fits to ./science/mastDownload/HST/ieyp12t3q/ieyp12t3q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t3q_flc.fits to ./science/mastDownload/HST/ieyp12t3q/ieyp12t3q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t1q_raw.fits to ./science/mastDownload/HST/ieyp12t1q/ieyp12t1q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t1q_flc.fits to ./science/mastDownload/HST/ieyp12t1q/ieyp12t1q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t7q_raw.fits to ./science/mastDownload/HST/ieyp12t7q/ieyp12t7q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t7q_flc.fits to ./science/mastDownload/HST/ieyp12t7q/ieyp12t7q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11siq_raw.fits to ./science/mastDownload/HST/ieyp11siq/ieyp11siq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11siq_flc.fits to ./science/mastDownload/HST/ieyp11siq/ieyp11siq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11seq_raw.fits to ./science/mastDownload/HST/ieyp11seq/ieyp11seq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11seq_flc.fits to ./science/mastDownload/HST/ieyp11seq/ieyp11seq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sfq_raw.fits to ./science/mastDownload/HST/ieyp11sfq/ieyp11sfq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sfq_flc.fits to ./science/mastDownload/HST/ieyp11sfq/ieyp11sfq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp10rsq_raw.fits to ./science/mastDownload/HST/ieyp10rsq/ieyp10rsq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp10rsq_flc.fits to ./science/mastDownload/HST/ieyp10rsq/ieyp10rsq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sbq_raw.fits to ./science/mastDownload/HST/ieyp11sbq/ieyp11sbq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sbq_flc.fits to ./science/mastDownload/HST/ieyp11sbq/ieyp11sbq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sdq_raw.fits to ./science/mastDownload/HST/ieyp11sdq/ieyp11sdq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11sdq_flc.fits to ./science/mastDownload/HST/ieyp11sdq/ieyp11sdq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11saq_raw.fits to ./science/mastDownload/HST/ieyp11saq/ieyp11saq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11saq_flc.fits to ./science/mastDownload/HST/ieyp11saq/ieyp11saq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp09r9q_raw.fits to ./science/mastDownload/HST/ieyp09r9q/ieyp09r9q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp09r9q_flc.fits to ./science/mastDownload/HST/ieyp09r9q/ieyp09r9q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t0q_raw.fits to ./science/mastDownload/HST/ieyp12t0q/ieyp12t0q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t0q_flc.fits to ./science/mastDownload/HST/ieyp12t0q/ieyp12t0q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t8q_raw.fits to ./science/mastDownload/HST/ieyp12t8q/ieyp12t8q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12t8q_flc.fits to ./science/mastDownload/HST/ieyp12t8q/ieyp12t8q_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12syq_raw.fits to ./science/mastDownload/HST/ieyp12syq/ieyp12syq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp12syq_flc.fits to ./science/mastDownload/HST/ieyp12syq/ieyp12syq_flc.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11skq_raw.fits to ./science/mastDownload/HST/ieyp11skq/ieyp11skq_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieyp11skq_flc.fits to ./science/mastDownload/HST/ieyp11skq/ieyp11skq_flc.fits ... [Done]
# <Table length=1016>
#                        Local Path                        Status  Message  URL
#                          str55                            str8    object object
# ------------------------------------------------------- -------- ------- ------
# ./science/mastDownload/HST/ielu07raq/ielu07raq_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ielu07raq/ielu07raq_flc.fits COMPLETE    None   None
# ./science/mastDownload/HST/ielu06q5q/ielu06q5q_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ielu06q5q/ielu06q5q_flc.fits COMPLETE    None   None
# ./science/mastDownload/HST/ielu07qxq/ielu07qxq_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ielu07qxq/ielu07qxq_flc.fits COMPLETE    None   None
# ./science/mastDownload/HST/ielu07rgq/ielu07rgq_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ielu07rgq/ielu07rgq_flc.fits COMPLETE    None   None
# ./science/mastDownload/HST/ielu07r3q/ielu07r3q_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ielu07r3q/ielu07r3q_flc.fits COMPLETE    None   None
#                                                     ...      ...     ...    ...
# ./science/mastDownload/HST/ieyp09r9q/ieyp09r9q_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ieyp09r9q/ieyp09r9q_flc.fits COMPLETE    None   None
# ./science/mastDownload/HST/ieyp12t0q/ieyp12t0q_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ieyp12t0q/ieyp12t0q_flc.fits COMPLETE    None   None
# ./science/mastDownload/HST/ieyp12t8q/ieyp12t8q_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ieyp12t8q/ieyp12t8q_flc.fits COMPLETE    None   None
# ./science/mastDownload/HST/ieyp12syq/ieyp12syq_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ieyp12syq/ieyp12syq_flc.fits COMPLETE    None   None
# ./science/mastDownload/HST/ieyp11skq/ieyp11skq_raw.fits COMPLETE    None   None
# ./science/mastDownload/HST/ieyp11skq/ieyp11skq_flc.fits COMPLETE    None   None

# %%
files_fits = glob.glob(working_directory + '/mastDownload/HST/*/*flc.fits')
print(len(files_fits))
test = files_fits[:]
# Out:
# 0

# %%
file_name = []
prop_id = []
paths = []
rootname = []
obsdate = []
obstime = []
shutter = []
flash_lvl = []
flash_dur = []

flash_cur = []
subarray = []
exp_time = []

for f in test:
    print(f)
    try:
        data = fits.open(f)
        rootname_val = data[0].header['ROOTNAME']
        filename_val = data[0].header['FILENAME']
        propid_val = data[0].header['PROPOSID']
        date_val = data[0].header['DATE-OBS']
        time_val = data[0].header['TIME-OBS']
        exptime_val = data[0].header['EXPTIME']
        subarray_val = data[0].header['SUBARRAY']
        flash_dur_val = data[0].header['FLASHDUR']
        flash_cur_val = data[0].header['FLASHCUR']
        flash_lvl_val = data[0].header['FLASHLVL']
        shutter_val = data[0].header['SHUTRPOS']
        print(rootname_val)

        file_name.append(filename_val)
        prop_id.append(propid_val)
        paths.append(f)
        rootname.append(rootname_val)
        obsdate.append(date_val)
        obstime.append(time_val)
        shutter.append(shutter_val)
        flash_lvl.append(flash_lvl_val)
        flash_dur.append(flash_dur_val)
        flash_cur.append(flash_cur_val)
        subarray.append(subarray_val)
        exp_time.append(exptime_val)

        data.close()
    except: 
        print('File is corrupt and could not open.')

# %%
dict = {'filename':file_name,'propid': prop_id, 'path': paths, 'rootname': rootname, 
        'obsdate': obsdate, 'obstime': obstime, 'shutter': shutter, 'flash_lvl': flash_lvl,
        'flash_dur': flash_dur, 'flash_cur': flash_cur, 'subarray': subarray,
        'exp_time': exp_time}

postflash_data = pd.DataFrame(dict) 

postflash_data = postflash_data.set_index('rootname')

postflash_data.to_pickle(database_filename)

# %%
postflash_data

# %%
postflash_data = pd.read_pickle(database_filename)
subarray_pf = postflash_data.loc[(postflash_data['subarray'] == True)] 
fullframe_pf = postflash_data.loc[(postflash_data['subarray'] == False)] 
sub_paths = subarray_pf.path.tolist()
all_paths = postflash_data.path.tolist()
print (all_paths)

# %%
means = []
sig_means = []
medians = []
sig_medians = []
stds = []
sig_stds = []

for f in all_paths:
    path = f
    print(path)
    data = fits.getdata(path)
    data_clip = stats.sigma_clip(data, 3)
    
    mean = np.mean(data)
    sig_mean = np.mean(data_clip)
    median = np.median(data)
    sig_median = np.median(data_clip)
    std = np.std(data)
    sig_std = np.std(data_clip)
    
    
    means.append(mean)
    sig_means.append(sig_mean)
    medians.append(median)
    sig_medians.append(sig_median)
    stds.append(std)
    sig_stds.append(sig_std)

# %%
dict = {'path': all_paths, 'mean': means, 'sig_mean': sig_means,'median': medians, 'sig_median': sig_medians, 'std': stds, 'sig_std': sig_stds}
path_and_stats_sub = pd.DataFrame(dict)

all_stats = pd.merge(left=postflash_data, right=path_and_stats_sub, left_on='path', right_on='path').set_index(postflash_data.index)

# %%
all_stats['norm_by_dur'] = (all_stats['sig_mean']/all_stats['flash_dur'])
all_stats.to_pickle(updated_filename)
all_stats = pd.read_pickle(updated_filename)
print (all_stats)

# %%
all_stats['datetime'] = pd.to_datetime(all_stats['obsdate'] + ' ' + all_stats['obstime'])
all_stats.to_pickle(updated_filename)
